# %%
import pandas as pd
from sqlite3 import connect
import numpy as np
import seaborn as sns

# %%
tabla=pd.read_csv(r'tabla.csv')
tabla.drop('Unnamed: 0',axis=1,inplace=True)

# %%
tabla
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 177  2000  Venezuela   317753.0               1013738.0        -4540.0
# 178  2005  Venezuela   437087.0               1076474.0       -22740.0
# 179  2010  Venezuela   560528.0               1347347.0      -200220.0
# 180  2015  Venezuela   709140.0               1404448.0      -431040.0
# 181  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
tabla.Country.unique()
# Out:
# array(['Argentina', 'Bahamas', 'Barbados', 'Bolivia', 'Brazil', 'Canada',
#        'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Ecuador',
#        'El Salvador', 'Guatemala', 'Guyana', 'Haiti', 'Honduras',
#        'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru',
#        'Puerto Rico', 'United States', 'Uruguay', 'Venezuela'],
#       dtype=object)

# %%
inflacion_argentina=pd.read_csv(r'inflacion_argentina.csv')
inflacion_bahamas=pd.read_csv(r'inflacion_bahamas.csv')
inflacion_barbados=pd.read_csv(r'inflacion_barbados.csv')
inflacion_bolivia=pd.read_csv(r'inflacion_bolivia.csv')
inflacion_brazil=pd.read_csv(r'inflacion_brazil.csv')
inflacion_canada=pd.read_csv(r'inflacion_canada.csv')
inflacion_chile=pd.read_csv(r'inflacion_chile.csv')
inflacion_colombia=pd.read_csv(r'inflacion_colombia.csv')
inflacion_costarica=pd.read_csv(r'inflacion_costarica.csv')
inflacion_ecuador=pd.read_csv(r'inflacion_ecuador.csv')
inflacion_elsalvador=pd.read_csv(r'inflacion_elsalvador.csv')
inflacion_guatemala=pd.read_csv(r'inflacion_guatemala.csv')
inflacion_guyana=pd.read_csv(r'inflacion_guyana.csv')
inflacion_haiti=pd.read_csv(r'inflacion_haiti.csv')
inflacion_honduras=pd.read_csv(r'inflacion_honduras.csv')
inflacion_jamaica=pd.read_csv(r'inflacion_jamaica.csv')
inflacion_mexico=pd.read_csv(r'inflacion_mexico.csv')
inflacion_nicaragua=pd.read_csv(r'inflacion_nicaragua.csv')
inflacion_panama=pd.read_csv(r'inflacion_panama.csv')
inflacion_paraguay=pd.read_csv(r'inflacion_paraguay.csv')
inflacion_peru=pd.read_csv(r'inflacion_peru.csv')
inflacion_uruguay=pd.read_csv(r'inflacion_uruguay.csv')
inflacion_usa=pd.read_csv(r'inflacion_usa.csv')
inflacion_venezuela=pd.read_csv(r'inflacion_venezuela.csv')

# %%
inflacion_argentina.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_argentina['country']='Argentina'
inflacion_bahamas.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_bahamas['country']='Bahamas'
inflacion_barbados.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_barbados['country']='Barbados'
inflacion_brazil.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_brazil['country']='Brazil'
inflacion_bolivia.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_bolivia['country']='Bolivia'
inflacion_canada.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_canada['country']='Canada'
inflacion_chile.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_chile['country']='Chile'
inflacion_colombia.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_colombia['country']='Colombia'
inflacion_costarica.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_costarica['country']='Costa Rica'
inflacion_ecuador.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_ecuador['country']='Ecuador'
inflacion_elsalvador.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_elsalvador['country']='El Salvador'
inflacion_guatemala.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_guatemala['country']='Guatemala'
inflacion_guyana.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_guyana['country']='Guyana'
inflacion_haiti.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_haiti['country']='Haiti'
inflacion_honduras.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_honduras['country']='Honduras'
inflacion_jamaica.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_jamaica['country']='Jamaica'
inflacion_mexico.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_mexico['country']='Mexico'
inflacion_nicaragua.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_nicaragua['country']='Nicaragua'
inflacion_panama.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_panama['country']='Panama'
inflacion_paraguay.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_paraguay['country']='Paraguay'
inflacion_peru.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_peru['country']='Peru'
inflacion_uruguay.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_uruguay['country']='Uruguay'
inflacion_usa.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_usa['country']='United States'
inflacion_venezuela.drop(['web-scraper-order','web-scraper-start-url'],axis=1,inplace=True)
inflacion_venezuela['country']='Venezuela'

# %%
prueba = pd.concat([inflacion_argentina,inflacion_bahamas,inflacion_barbados,inflacion_bolivia,inflacion_brazil,inflacion_canada,inflacion_chile,inflacion_colombia,inflacion_costarica,inflacion_ecuador,inflacion_elsalvador,inflacion_guatemala,inflacion_guyana,inflacion_haiti,inflacion_honduras,inflacion_jamaica,inflacion_mexico,inflacion_nicaragua,inflacion_panama,inflacion_paraguay,inflacion_peru,inflacion_uruguay,inflacion_usa,inflacion_venezuela], axis=0,ignore_index=True)

# %%
prueba
# Out:
#        Año inflacion    country
# 0     2022   94,80 %  Argentina
# 1     2021   48,41 %  Argentina
# 2     2020   42,02 %  Argentina
# 3     2019   53,55 %  Argentina
# 4     2018   34,28 %  Argentina
# ...    ...       ...        ...
# 1342  1984   11,57 %  Venezuela
# 1343  1983    6,34 %  Venezuela
# 1344  1982    9,66 %  Venezuela
# 1345  1981   16,05 %  Venezuela
# 1346  1980   21,54 %  Venezuela
#
# [1347 rows x 3 columns]

# %%
prueba['inflacion']=prueba['inflacion'].apply(lambda x: x.replace("%",""))
prueba['inflacion']=prueba['inflacion'].apply(lambda x: x.replace(".",""))
prueba['inflacion']=prueba['inflacion'].apply(lambda x: x.replace(",","."))

# %%
prueba.tail(10)
# Out:
#        Año inflacion    country
# 1337  1989    84.46   Venezuela
# 1338  1988    29.47   Venezuela
# 1339  1987    28.14   Venezuela
# 1340  1986    11.54   Venezuela
# 1341  1985    11.38   Venezuela
# 1342  1984    11.57   Venezuela
# 1343  1983     6.34   Venezuela
# 1344  1982     9.66   Venezuela
# 1345  1981    16.05   Venezuela
# 1346  1980    21.54   Venezuela

# %%
conn = connect(':memory:')
tabla.to_sql('tab',conn,index=False)
prueba.to_sql('pru',conn,index=False)
# Out:
# 1347

# %%
tabla_2=pd.read_sql('SELECT tab.*,pru.inflacion as Inflation FROM tab tab JOIN pru pru ON(tab.Year=pru.Año AND tab.Country=pru.country)',conn)

# %%
tabla_2.Country.unique()
# Out:
# array(['Argentina', 'Bahamas', 'Barbados', 'Bolivia', 'Brazil', 'Canada',
#        'Chile', 'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador',
#        'Guatemala', 'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico',
#        'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'United States',
#        'Uruguay', 'Venezuela'], dtype=object)

# %%
tabla_2[tabla_2.Country=='Venezuela']
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 161  1990  Venezuela   185492.0               1025009.0          920.0
# 162  1995  Venezuela   241864.0               1019996.0        -2270.0
# 163  2000  Venezuela   317753.0               1013738.0        -4540.0
# 164  2005  Venezuela   437087.0               1076474.0       -22740.0
# 165  2010  Venezuela   560528.0               1347347.0      -200220.0
# 166  2015  Venezuela   709140.0               1404448.0      -431040.0
# 167  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 161               0.010    19750580            0.009392
# 162              -0.022    22107288            0.010940
# 163              -0.039    24427732            0.013008
# 164              -0.180    26668790            0.016389
# 165              -1.460    28715026            0.019520
# 166              -2.946    30529722            0.023228
# ...

# %%
pib=pd.read_csv('pib.csv')

# %%
pib=pib[pib['Country Name'].isin(['Argentina', 'Bahamas', 'Barbados', 'Bolivia', 'Brazil', 'Canada',
       'Chile', 'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador',
       'Guatemala', 'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico',
       'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'United States',
       'Uruguay', 'Venezuela'])]

# %%
pib=pib.loc[:,['Country Name','1990','1995','2000',
       '2005','2010',  '2015','2020']]

# %%
pib.reset_index(inplace=True,drop=True)

# %%
pib
# Out:
#      Country Name      1990      1995      2000      2005       2010  \
# 0       Argentina -2.467214 -2.845210 -0.788999  8.851660  10.125398
# 1         Bolivia  4.635787  4.678277  2.507811  4.421433   4.126723
# 2          Brazil -4.350000  4.223794  4.387949  3.202132   7.528226
# 3        Barbados -3.307593  2.013998  4.447190  3.955458  -2.365165
# 4          Canada       NaN       NaN  5.177636  3.204200   3.089495
# 5           Chile  3.333565  8.933296  4.971621  5.837046   5.851651
# 6        Colombia  4.281998  5.202438  2.924861  4.828761   4.494659
# 7      Costa Rica  3.553063  4.153953  3.868718  3.976666   5.360343
# 8         Ecuador  3.679914  2.252549  1.091802  5.291308   3.525299
# 9       Guatemala  3.102563  4.948548  3.608869  3.276027   2.884175
# 10         Guyana -3.067485  5.031447 -1.363804 -1.950958   4.138442
# 11       Honduras  2.791749  6.189305  7.291288  6.050599   3.731140
# 12          Haiti  1.038123  9.897707  0.870059  3.072173  -5.651512
# ...

# %%
PBI=pd.DataFrame({
    'Country':['Argentina','Argentina','Argentina','Argentina','Argentina','Argentina','Argentina','Bolivia','Bolivia','Bolivia','Bolivia','Bolivia','Bolivia','Bolivia','Brazil','Brazil','Brazil','Brazil','Brazil','Brazil','Brazil','Barbados','Barbados','Barbados','Barbados','Barbados','Barbados','Barbados','Canada','Canada','Canada','Canada','Canada','Canada','Canada','Chile','Chile','Chile','Chile','Chile','Chile','Chile','Colombia','Colombia','Colombia','Colombia','Colombia','Colombia','Colombia','Costa Rica','Costa Rica','Costa Rica','Costa Rica','Costa Rica','Costa Rica','Costa Rica','Ecuador','Ecuador','Ecuador','Ecuador','Ecuador','Ecuador','Ecuador','Guatemala','Guatemala','Guatemala','Guatemala','Guatemala','Guatemala','Guatemala','Guyana','Guyana','Guyana','Guyana','Guyana','Guyana','Guyana','Honduras','Honduras','Honduras','Honduras','Honduras','Honduras','Honduras','Haiti','Haiti','Haiti','Haiti','Haiti','Haiti','Haiti','Jamaica','Jamaica','Jamaica','Jamaica','Jamaica','Jamaica','Jamaica','Mexico','Mexico','Mexico','Mexico','Mexico','Mexico','Mexico','Nicaragua','Nicaragua','Nicaragua','Nicaragua','Nicaragua','Nicaragua','Nicaragua','Panama','Panama','Panama','Panama','Panama','Panama','Panama','Peru','Peru','Peru','Peru','Peru','Peru','Peru','Paraguay','Paraguay','Paraguay','Paraguay','Paraguay','Paraguay','Paraguay','El Salvador','El Salvador','El Salvador','El Salvador','El Salvador','El Salvador','El Salvador','Uruguay','Uruguay','Uruguay','Uruguay','Uruguay','Uruguay','Uruguay','United States','United States','United States','United States','United States','United States','United States','Venezuela','Venezuela','Venezuela','Venezuela','Venezuela','Venezuela','Venezuela'],
    'Year':['1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020','1990', '1995', '2000', '2005', '2010', '2015', '2020'],
    'PBI':[ -2.46721377810472, -2.84520961057079,
        -0.78899893905691, 8.85165992013437, 10.1253981561002,
        2.73115982828944, -9.94323513446069, 4.6357874278518, 4.67827659709971, 2.50781080899483,
        4.42143312687979, 4.1267225910567, 4.85718730035796,
        -8.73788443399144, -4.35000000000022, 4.22379363350413, 4.38794944745618,
        3.20213206130431, 7.52822581815364, -3.54576339269425,
        -3.87867633397198, -3.30759330759331, 2.01399800028568,
        4.44718962322422, 3.95545760352627, -2.36516470308347,
        2.47261987248125, -13.3110215258234, 0.2, 2.7, 5.17763566824114, 3.20420042827129,
        3.08949461982786, 0.659176863558869, -5.23302430280606, 3.33356547444561, 8.93329586932387, 4.9716214882971,
        5.83704571917758, 5.85165102224047, 2.15194249981184,
        -5.9782240617438, 4.28199833053058, 5.2024375925092, 2.92486148314592,
        4.82876110795085, 4.49465897070922, 2.95590137527523,
        -7.04815120786543, 3.55306336572285, 4.15395304305277,
        3.86871808818643, 3.97666636792908, 5.36034347985841,
        3.65208096802883, -4.05090817067276, 3.67991405278418, 2.25254877423716, 1.0918015643576,
        5.29130826699402, 3.52529866894027, 0.0988726083462694,
        -7.78760709093422, 3.10256317557587, 4.94854750210382, 3.6088687174876,
        3.27602692588886, 2.88417542800377, 4.09217081621244,
        -1.76408292563957, -3.06748466406728, 5.03144655812085, -1.36380390261873,
        -1.95095759501714, 4.13844160137342, 0.687521210092171,
        43.4795559399402, 2.7917489495977, 6.18930455759235, 7.29128815869618,
        6.05059922215973, 3.73114034433009, 3.84007997093951,
        -8.96476018404584, 1.03812280198248, 9.89770748815705, 0.870059259424892,
        3.07217337664731, -5.65151153448299, 2.5625088349003,
        -3.34337261175989, 4.2005351147029, 2.34995704147829, 0.87870354796236,
        0.893797935945003, -1.45714720947502, 0.92148712538031, -10.0, 5.17576838681073, -6.29123082110117, 4.94245371467422,
        2.30780706591736, 5.11811814321163, 3.29315152833387,
        -7.98791234014749, -0.0524997212687737, 5.91190795714505,
        4.10159023598223, 4.28239836333562, 4.40964549908733,
        4.79205676554646, -1.7899754441716, 8.09899300573198, 1.7516787571155, 2.71537415482821,
        7.19127940233535, 5.82799349428571, 5.7330542960121,
        -17.9448935972493, -4.98256353646605, 7.41139504735119, 2.69437139806912,
        6.28506032509601, 8.33245910749577, 3.25224477218451,
        -10.9526989325015, 4.12328287941739, 6.82281030358578,
        -2.31414056819045, 2.13349066459601, 11.0952312685521,
        2.95715173487106, -0.819785390971916, 4.83290057793786, 4.73408140229732,
        1.12790697674419, 2.70546347259486, 2.10788757932909,
        2.40000000000001, -8.17721743762763, 0.297348378681562, -1.44759896894408,
        -1.92993063772035, 7.46013213775913, 7.80340966564692,
        0.370741265001499, -6.12147627999001, 1.88596495668033, 2.68421727207786,
        4.07715947941618, 3.48322032025258, 2.70885669419681,
        2.70636958176399, -2.76780251140578,6.5,4,3.7,10.3,-1.5,-15.7,-19.7]})

# %%
PBI
# Out:
#        Country  Year        PBI
# 0    Argentina  1990  -2.467214
# 1    Argentina  1995  -2.845210
# 2    Argentina  2000  -0.788999
# 3    Argentina  2005   8.851660
# 4    Argentina  2010  10.125398
# ..         ...   ...        ...
# 156  Venezuela  2000   3.700000
# 157  Venezuela  2005  10.300000
# 158  Venezuela  2010  -1.500000
# 159  Venezuela  2015 -15.700000
# 160  Venezuela  2020 -19.700000
#
# [161 rows x 3 columns]

# %%
tabla_2
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 163  2000  Venezuela   317753.0               1013738.0        -4540.0
# 164  2005  Venezuela   437087.0               1076474.0       -22740.0
# 165  2010  Venezuela   560528.0               1347347.0      -200220.0
# 166  2015  Venezuela   709140.0               1404448.0      -431040.0
# 167  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
PBI.to_sql('pbi',conn,index=False)
tabla_2.to_sql('t2',conn,index=False)
# Out:
# 168

# %%
tabla_3=pd.read_sql('SELECT t2.*,pbi.PBI FROM t2 t2 JOIN pbi pbi ON(t2.Year=pbi.Year AND t2.Country=pbi.Country)',conn)

# %%
tabla_3
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 156  2000  Venezuela   317753.0               1013738.0        -4540.0
# 157  2005  Venezuela   437087.0               1076474.0       -22740.0
# 158  2010  Venezuela   560528.0               1347347.0      -200220.0
# 159  2015  Venezuela   709140.0               1404448.0      -431040.0
# 160  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
poblacion_mujeres=pd.read_csv(r'rangos/population-and-demography_female.csv')

# %%
poblacion_mujeres.columns
# Out:
# Index(['Country name', 'Year', 'Female population',
#        'Female population of children under the age of 1',
#        'Female population of children under the age of 5',
#        'Female population of children under the age of 15',
#        'Female population under the age of 25',
#        'Female population aged 15 to 64 years', 'Female population at age 1',
#        'Female population aged 1 to 4 years',
#        'Female population aged 5 to 9 years',
#        'Female population aged 10 to 14 years',
#        'Female population aged 15 to 19 years',
#        'Female population aged 20 to 29 years',
#        'Female population aged 30 to 39 years',
#        'Female population aged 40 to 49 years',
#        'Female population aged 50 to 59 years',
#        'Female population aged 60 to 69 years',
#        'Female population aged 70 to 79 years',
#        'Female population aged 80 to 89 years',
#        'Female population aged 90 to 99 years',
# ...

# %%
poblacion_mujeres.to_sql('muj',conn,index=False)
tabla_3.to_sql('t3',conn,index=False)
# Out:
# 161

# %%
poblacion_mujeres
# Out:
#       Country name  Year  Female population  \
# 0      Afghanistan  1950            3518204
# 1      Afghanistan  1951            3569934
# 2      Afghanistan  1952            3624223
# 3      Afghanistan  1953            3679048
# 4      Afghanistan  1954            3735087
# ...            ...   ...                ...
# 18283     Zimbabwe  2017            7810481
# 18284     Zimbabwe  2018            7966188
# 18285     Zimbabwe  2019            8122623
# 18286     Zimbabwe  2020            8284452
# 18287     Zimbabwe  2021            8449840
#
#        Female population of children under the age of 1  \
# 0                                              151011.0
# 1                                              148525.0
# 2                                              151477.0
# 3                                              154481.0
# 4                                              157375.0
# ...                                                 ...
# ...

# %%
tabla_4=pd.read_sql('SELECT t3.*,muj.`Female population`,muj.`Female population aged 20 to 29 years`,muj.`Female population aged 30 to 39 years`,muj.`Female population aged 40 to 49 years`,muj.`Female population aged 50 to 59 years`,muj.`Female population aged 60 to 69 years` FROM t3 t3 JOIN muj muj ON(t3.Year=muj.Year AND t3.Country=muj.`Country name`)',conn)

# %%
tabla_4
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 156  2000  Venezuela   317753.0               1013738.0        -4540.0
# 157  2005  Venezuela   437087.0               1076474.0       -22740.0
# 158  2010  Venezuela   560528.0               1347347.0      -200220.0
# 159  2015  Venezuela   709140.0               1404448.0      -431040.0
# 160  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
poblacion_hombres=pd.read_csv(r'rangos/population-and-demography_male.csv')
poblacion_hombres.to_sql('hom',conn,index=False)
tabla_4.to_sql('t4',conn,index=False)
# Out:
# 161

# %%
poblacion_hombres.columns
# Out:
# Index(['Country name', 'Year', 'Male population',
#        'Male population of children under the age of 1',
#        'Male population of children under the age of 5',
#        'Male population of children under the age of 15',
#        'Male population under the age of 25',
#        'Male population aged 15 to 64 years', 'Male population at age 1',
#        'Male population aged 1 to 4 years',
#        'Male population aged 5 to 9 years',
#        'Male population aged 10 to 14 years',
#        'Male population aged 15 to 19 years',
#        'Male population aged 20 to 29 years',
#        'Male population aged 30 to 39 years',
#        'Male population aged 40 to 49 years',
#        'Male population aged 50 to 59 years',
#        'Male population aged 60 to 69 years',
#        'Male population aged 70 to 79 years',
#        'Male population aged 80 to 89 years',
#        'Male population aged 90 to 99 years',
#        'Male population older than 100 years'],
#       dtype='object')

# %%
tabla_5=pd.read_sql('SELECT t4.*,hom.`Male population`,hom.`Male population aged 20 to 29 years`,hom.`Male population aged 30 to 39 years`,hom.`Male population aged 40 to 49 years`,hom.`Male population aged 50 to 59 years`,hom.`Male population aged 60 to 69 years` FROM t4 t4 JOIN hom hom ON(t4.Year=hom.Year AND t4.Country=hom.`Country name`)',conn)

# %%
tabla_5
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 156  2000  Venezuela   317753.0               1013738.0        -4540.0
# 157  2005  Venezuela   437087.0               1076474.0       -22740.0
# 158  2010  Venezuela   560528.0               1347347.0      -200220.0
# 159  2015  Venezuela   709140.0               1404448.0      -431040.0
# 160  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
pobrangent=pd.read_csv(r'rangos/population-and-demography_pobranget.csv')

# %%
pobrangent.columns
# Out:
# Index(['Country name', 'Year', 'Population',
#        'Population of children under the age of 1',
#        'Population of children under the age of 5',
#        'Population of children under the age of 15',
#        'Population under the age of 25', 'Population aged 15 to 64 years',
#        'Population at age 1', 'Population aged 1 to 4 years',
#        'Population aged 5 to 9 years', 'Population aged 10 to 14 years',
#        'Population aged 15 to 19 years', 'Population aged 20 to 29 years',
#        'Population aged 30 to 39 years', 'Population aged 40 to 49 years',
#        'Population aged 50 to 59 years', 'Population aged 60 to 69 years',
#        'Population aged 70 to 79 years', 'Population aged 80 to 89 years',
#        'Population aged 90 to 99 years', 'Population older than 100 years'],
#       dtype='object')

# %%
pobrangent.to_sql('pob',conn,index=False)
tabla_5.to_sql('t5',conn,index=False)
# Out:
# 161

# %%
tabla_6=pd.read_sql('SELECT t5.*,pob.`Population aged 20 to 29 years`,pob.`Population aged 30 to 39 years`,pob.`Population aged 40 to 49 years`,pob.`Population aged 50 to 59 years`,pob.`Population aged 60 to 69 years` FROM t5 t5 JOIN pob pob ON(t5.Year=pob.Year AND t5.Country=pob.`Country name`)',conn)

# %%
tabla_6
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 156  2000  Venezuela   317753.0               1013738.0        -4540.0
# 157  2005  Venezuela   437087.0               1076474.0       -22740.0
# 158  2010  Venezuela   560528.0               1347347.0      -200220.0
# 159  2015  Venezuela   709140.0               1404448.0      -431040.0
# 160  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
tabla_6.to_csv('tabla_6.csv')

# %%
tabla_6.Country.unique()
# Out:
# array(['Argentina', 'Barbados', 'Bolivia', 'Brazil', 'Canada', 'Chile',
#        'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador', 'Guatemala',
#        'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua',
#        'Panama', 'Paraguay', 'Peru', 'United States', 'Uruguay',
#        'Venezuela'], dtype=object)

# %%
retornos=pd.read_csv(r'retornos_paises_3.csv')

# %%
retornos
# Out:
#      Year    Country  Returns by origin  Returns by host
# 0    1990  Argentina                 77                2
# 1    1995  Argentina                 89                3
# 2    2000  Argentina                 57                9
# 3    2005  Argentina                 40               12
# 4    2010  Argentina                 41                4
# ..    ...        ...                ...              ...
# 156  2000  Venezuela                 40                0
# 157  2005  Venezuela                 57                0
# 158  2010  Venezuela                 48                1
# 159  2015  Venezuela                 62               15
# 160  2020  Venezuela                 63                1
#
# [161 rows x 4 columns]

# %%
retornos.to_sql('ret',conn,index=False)
tabla_6.to_sql('t6',conn,index=False)
# Out:
# 161

# %%
tabla_7=pd.read_sql('SELECT t6.*,ret.`Returns by origin`,ret.`Returns by host` FROM t6 t6 JOIN ret ret ON(t6.Year=ret.Year AND t6.Country=ret.Country)',conn)

# %%
tabla_7.iloc[:,0:10]
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 156  2000  Venezuela   317753.0               1013738.0        -4540.0
# 157  2005  Venezuela   437087.0               1076474.0       -22740.0
# 158  2010  Venezuela   560528.0               1347347.0      -200220.0
# 159  2015  Venezuela   709140.0               1404448.0      -431040.0
# 160  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
tabla_7.iloc[:,10:20]
# Out:
#     Inflation        PBI  Female population  \
# 0    2313.96   -2.467214           16574139
# 1       3.38   -2.845210           17725496
# 2      -0.94   -0.788999           18790032
# 3       9.64    8.851660           19791350
# 4      10.78   10.125398           20791630
# ..        ...        ...                ...
# 156    16.20    3.700000           12185779
# 157    15.95   10.300000           13329256
# 158    28.19   -1.500000           14393136
# 159   121.74  -15.700000           15341132
# 160  2959.80  -19.700000           14376694
#
#      Female population aged 20 to 29 years  \
# 0                                  2402180
# 1                                  2627136
# 2                                  2957242
# 3                                  3148745
# 4                                  3218134
# ..                                     ...
# 156                                2130889
# 157                                2330427
# ...

# %%
tabla_7.iloc[:,20:32]
# Out:
#      Male population aged 30 to 39 years  Male population aged 40 to 49 years  \
# 0                                2185065                              1803790
# 1                                2283855                              1976592
# 2                                2383544                              2100097
# 3                                2602666                              2199919
# 4                                2966829                              2304458
# ..                                   ...                                  ...
# 156                              1729320                              1273572
# 157                              1886584                              1490131
# 158                              2049331                              1645869
# 159                              2200664                              1776072
# 160                              1897047                              1714696
#
# ...

# %%
tabla_7.Country.unique()
# Out:
# array(['Argentina', 'Barbados', 'Bolivia', 'Brazil', 'Canada', 'Chile',
#        'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador', 'Guatemala',
#        'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua',
#        'Panama', 'Paraguay', 'Peru', 'United States', 'Uruguay',
#        'Venezuela'], dtype=object)

# %%
tabla_7.to_csv('tabla_7.csv')

# %%
desaparecidos=pd.read_csv(r'Missing_Migrants_regiones.csv')

# %%
desaparecidos['Region of Incident'].unique()
# Out:
# array(['North America', 'Europe', 'Mediterranean', 'Caribbean',
#        'South-eastern Asia', 'Southern Asia', 'Eastern Africa',
#        'Central America', 'Northern Africa', 'Eastern Asia',
#        'Western Asia', 'Western Africa', 'South America',
#        'Southern Africa', 'Middle Africa', 'Central Asia'], dtype=object)

# %%
desaparecidos=desaparecidos[desaparecidos['Region of Incident'].isin(['North America','Central America','Caribbean' ,'South America'])]

# %%
desaparecidos=desaparecidos[desaparecidos['Region of Origin'].isin(['North America','Central America','Caribbean' ,'South America'])]

# %%
desaparecidos['Incident year'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#       dtype=int64)

# %%
desaparecidos.to_sql('des',conn,index=False)
# Out:
# 2048

# %%
des=pd.read_sql('SELECT `Region of Incident`,SUM(`Total Number of Dead and Missing`) as total,`Incident year`,`Region of Origin` FROM des GROUP BY `Incident year`, `Region of Incident`',conn)

# %%
des
# Out:
#    Region of Incident  total  Incident year Region of Origin
# 0           Caribbean     73           2014        Caribbean
# 1     Central America    114           2014    South America
# 2       North America     20           2014  Central America
# 3           Caribbean     68           2015        Caribbean
# 4     Central America    100           2015  Central America
# 5       North America     31           2015  Central America
# 6       South America      2           2015        Caribbean
# 7           Caribbean    115           2016        Caribbean
# 8     Central America    152           2016  Central America
# 9       North America     97           2016  Central America
# 10      South America     30           2016    South America
# 11          Caribbean    169           2017        Caribbean
# 12    Central America     74           2017  Central America
# 13      North America    100           2017  Central America
# ...

# %%
des.to_csv('des.csv')

# %%
edad_migraciones=pd.read_csv('edad_migrantes.csv')

# %%
edad_migraciones.drop(['indicator.label','source.label','obs_status.label','note_classif.label','note_indicator.label','note_source.label'],axis=1, inplace=True)

# %%
edad_migraciones.head(3)
# Out:
#   ref_area.label    sex.label                classif1.label  \
# 0      Argentina  Sexo: Total  Edad (Jóvenes, adultos): 15+
# 1      Argentina  Sexo: Total  Edad (Jóvenes, adultos): 15+
# 2      Argentina  Sexo: Total  Edad (Jóvenes, adultos): 15+
#
#                                  classif2.label  time  obs_value
# 0                    Lugar de nacimiento: Total  2021  22223.212
# 1            Lugar de nacimiento: Nativo-nacido  2021  21063.382
# 2  Lugar de nacimiento: Nacido en el extranjero  2021   1141.924

# %%
edad_migraciones['ref_area.label'].unique()
# Out:
# array(['Argentina', 'Belice', 'Bolivia', 'Brasil', 'Barbados', 'Canadá',
#        'Chile', 'Colombia', 'Costa Rica', 'República Dominicana',
#        'Ecuador', 'Guatemala', 'Guyana', 'Honduras', 'Haití',
#        'Santa Lucía', 'México', 'Montserrat', 'Nicaragua', 'Panamá',
#        'Perú', 'Paraguay', 'Suriname', 'Trinidad y Tabago', 'Uruguay',
#        'Estados Unidos'], dtype=object)

# %%
edad_migraciones['ref_area.label'].replace({"Brasil": "Brazil","Canadá": "Canada","Haití": "Haiti","México": "Mexico","Panamá": "Panama","Perú":"Peru","Estados Unidos":"United States"},inplace=True)

# %%
edad_migraciones=edad_migraciones[edad_migraciones['ref_area.label'].isin(['Argentina', 'Barbados', 'Bolivia', 'Brazil', 'Canada', 'Chile',
       'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador', 'Guatemala',
       'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua',
       'Panama', 'Paraguay', 'Peru', 'United States', 'Uruguay','Venezuela'])]

# %%
edad_migraciones['ref_area.label'].unique()
# Out:
# array(['Argentina', 'Bolivia', 'Brazil', 'Barbados', 'Canada', 'Chile',
#        'Colombia', 'Costa Rica', 'Ecuador', 'Guatemala', 'Guyana',
#        'Honduras', 'Haiti', 'Mexico', 'Nicaragua', 'Panama', 'Peru',
#        'Paraguay', 'Uruguay', 'United States'], dtype=object)

# %%
edad_migraciones.rename(columns={"ref_area.label": "Country", "sex.label": "Gender","classif1.label":"Age","classif2.label":"nacionality","time":"Year","obs_value":"cantidad"},inplace=True)

# %%
edad_migraciones
# Out:
#              Country         Gender                             Age  \
# 0          Argentina    Sexo: Total    Edad (Jóvenes, adultos): 15+
# 1          Argentina    Sexo: Total    Edad (Jóvenes, adultos): 15+
# 2          Argentina    Sexo: Total    Edad (Jóvenes, adultos): 15+
# 3          Argentina    Sexo: Total    Edad (Jóvenes, adultos): 15+
# 4          Argentina    Sexo: Total  Edad (Jóvenes, adultos): 15-64
# ...              ...            ...                             ...
# 19927  United States  Sexo: Mujeres  Edad (Tramos agregados): 55-64
# 19928  United States  Sexo: Mujeres  Edad (Tramos agregados): 55-64
# 19929  United States  Sexo: Mujeres    Edad (Tramos agregados): 65+
# 19930  United States  Sexo: Mujeres    Edad (Tramos agregados): 65+
# 19931  United States  Sexo: Mujeres    Edad (Tramos agregados): 65+
#
#                                         nacionality  Year   cantidad
# 0                        Lugar de nacimiento: Total  2021  22223.212
# ...

# %%
edad_migraciones.Year.unique()
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2014, 2013, 2012, 2011, 2010, 2009,
#        2008, 2006, 2005, 2004, 1999, 2002, 2001, 2000, 2015, 2007, 2003,
#        1998, 1997, 1996, 1995, 2016, 2022, 1994], dtype=int64)

# %%
edad_migraciones.nacionality.unique()
# Out:
# array(['Lugar de nacimiento: Total', 'Lugar de nacimiento: Nativo-nacido',
#        'Lugar de nacimiento: Nacido en el extranjero',
#        'Lugar de nacimiento: Estado desconocido'], dtype=object)

# %%
edad_migraciones=edad_migraciones[edad_migraciones['nacionality']=='Lugar de nacimiento: Nacido en el extranjero']

# %%
edad_migraciones
# Out:
#              Country         Gender                             Age  \
# 2          Argentina    Sexo: Total    Edad (Jóvenes, adultos): 15+
# 6          Argentina    Sexo: Total  Edad (Jóvenes, adultos): 15-64
# 10         Argentina    Sexo: Total  Edad (Jóvenes, adultos): 15-24
# 14         Argentina    Sexo: Total    Edad (Jóvenes, adultos): 25+
# 18         Argentina  Sexo: Hombres    Edad (Jóvenes, adultos): 15+
# ...              ...            ...                             ...
# 19919  United States  Sexo: Mujeres  Edad (Tramos agregados): Total
# 19922  United States  Sexo: Mujeres  Edad (Tramos agregados): 15-24
# 19925  United States  Sexo: Mujeres  Edad (Tramos agregados): 25-54
# 19928  United States  Sexo: Mujeres  Edad (Tramos agregados): 55-64
# 19931  United States  Sexo: Mujeres    Edad (Tramos agregados): 65+
#
#                                         nacionality  Year   cantidad
# 2      Lugar de nacimiento: Nacido en el extranjero  2021   1141.924
# ...

# %%
edad_migraciones.drop('nacionality',axis=1,inplace=True)
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\1501597060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edad_migraciones.drop('nacionality',axis=1,inplace=True)

# %%
edad_migraciones.Age.unique()
# Out:
# array(['Edad (Jóvenes, adultos): 15+', 'Edad (Jóvenes, adultos): 15-64',
#        'Edad (Jóvenes, adultos): 15-24', 'Edad (Jóvenes, adultos): 25+',
#        'Edad (Tramos agregados): Total', 'Edad (Tramos agregados): 15-24',
#        'Edad (Tramos agregados): 25-54', 'Edad (Tramos agregados): 55-64',
#        'Edad (Tramos agregados): 65+'], dtype=object)

# %%
edad_migraciones['Age'].replace({"Edad (Jóvenes, adultos): 15+": "15+","Edad (Jóvenes, adultos): 15-64": "15-64","Edad (Jóvenes, adultos): 15-24": "15-24","Edad (Jóvenes, adultos): 25+": "25+","Edad (Tramos agregados): Total": "Total","Edad (Tramos agregados): 15-24":"15-24","Edad (Tramos agregados): 25-54":"25-54","Edad (Tramos agregados): 55-64":"55-64","Edad (Tramos agregados): 65+":"65+"},inplace=True)
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\2987036627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edad_migraciones['Age'].replace({"Edad (Jóvenes, adultos): 15+": "15+","Edad (Jóvenes, adultos): 15-64": "15-64","Edad (Jóvenes, adultos): 15-24": "15-24","Edad (Jóvenes, adultos): 25+": "25+","Edad (Tramos agregados): Total": "Total","Edad (Tramos agregados): 15-24":"15-24","Edad (Tramos agregados): 25-54":"25-54","Edad (Tramos agregados): 55-64":"55-64","Edad (Tramos agregados): 65+":"65+"},inplace=True)

# %%
edad_migraciones.Gender.unique()
# Out:
# array(['Sexo: Total', 'Sexo: Hombres', 'Sexo: Mujeres'], dtype=object)

# %%
edad_migraciones['Gender'].replace({"Sexo: Total": "Total","Sexo: Hombres": "Male","Sexo: Mujeres": "Female"},inplace=True)
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\2015878994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edad_migraciones['Gender'].replace({"Sexo: Total": "Total","Sexo: Hombres": "Male","Sexo: Mujeres": "Female"},inplace=True)

# %%
edad_migraciones.rename(columns={'cantidad':'Population'},inplace=True)
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\1913110274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edad_migraciones.rename(columns={'cantidad':'Population'},inplace=True)

# %%
edad_migraciones['Population']=edad_migraciones['Population']*1000
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\3040958639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edad_migraciones['Population']=edad_migraciones['Population']*1000

# %%
edad_migraciones.dropna(inplace=True)
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\3079934870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edad_migraciones.dropna(inplace=True)

# %%
edad_migraciones
# Out:
#              Country  Gender    Age  Year  Population
# 2          Argentina   Total    15+  2021   1141924.0
# 6          Argentina   Total  15-64  2021    852786.0
# 10         Argentina   Total  15-24  2021     99397.0
# 14         Argentina   Total    25+  2021   1042527.0
# 18         Argentina    Male    15+  2021    522285.0
# ...              ...     ...    ...   ...         ...
# 19919  United States  Female  Total  1994  11780470.0
# 19922  United States  Female  15-24  1994   1736389.0
# 19925  United States  Female  25-54  1994   7098287.0
# 19928  United States  Female  55-64  1994   1227293.0
# 19931  United States  Female    65+  1994   1718501.0
#
# [5179 rows x 5 columns]

# %%
edad_migraciones.Country.unique()
# Out:
# array(['Argentina', 'Bolivia', 'Brazil', 'Barbados', 'Canada', 'Chile',
#        'Colombia', 'Costa Rica', 'Ecuador', 'Guatemala', 'Guyana',
#        'Honduras', 'Haiti', 'Mexico', 'Nicaragua', 'Panama', 'Peru',
#        'Paraguay', 'Uruguay', 'United States'], dtype=object)

# %%
tabla_7.Country.unique()
# Out:
# array(['Argentina', 'Barbados', 'Bolivia', 'Brazil', 'Canada', 'Chile',
#        'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador', 'Guatemala',
#        'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua',
#        'Panama', 'Paraguay', 'Peru', 'United States', 'Uruguay',
#        'Venezuela'], dtype=object)

# %%
salarios=pd.read_csv(r'salario.csv')
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\3547523118.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   salarios=pd.read_csv(r'salario.csv')

# %%
salarios['ref_area.label'].unique()
# Out:
# array(['Aruba', 'Anguilla', 'Antillas Neerlandesas', 'Argentina',
#        'Bahamas', 'Belice', 'Bermudas', 'Bolivia', 'Brasil', 'Barbados',
#        'Canadá', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Curacao',
#        'República Dominicana', 'Ecuador', 'Islas Malvinas (Falkland)',
#        'Guatemala', 'Guyana', 'Honduras', 'Jamaica', 'Santa Lucía',
#        'México', 'Nicaragua', 'Panamá', 'Perú', 'Paraguay', 'El Salvador',
#        'Suriname', 'Trinidad y Tabago', 'Uruguay', 'Estados Unidos',
#        'Venezuela, República Bolivariana de'], dtype=object)

# %%
salarios['ref_area.label'].replace({"Brasil": "Brazil","Canadá": "Canada","Haití": "Haiti","México": "Mexico","Panamá": "Panama","Perú":"Peru","Estados Unidos":"United States","Venezuela, República Bolivariana de":"Venezuela"},inplace=True)

# %%
salarios=salarios[salarios['ref_area.label'].isin(['Argentina', 'Barbados', 'Bolivia', 'Brazil', 'Canada',
       'Chile', 'Colombia', 'Costa Rica', 'Ecuador', 'El Salvador',
       'Guatemala', 'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Mexico',
       'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'United States',
       'Uruguay', 'Venezuela'])]

# %%
salarios['ref_area.label'].unique()
# Out:
# array(['Argentina', 'Bolivia', 'Brazil', 'Barbados', 'Canada', 'Chile',
#        'Colombia', 'Costa Rica', 'Ecuador', 'Guatemala', 'Guyana',
#        'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Peru',
#        'Paraguay', 'El Salvador', 'Uruguay', 'United States', 'Venezuela'],
#       dtype=object)

# %%
salarios.drop(['indicator.label','source.label','obs_status.label','note_classif.label','note_indicator.label','note_source.label'],axis=1, inplace=True)

# %%
salarios['classif2.label'].unique()
# Out:
# array(['Divisa: Moneda local', 'Divisa: $ PPA 2017',
#        'Divisa: Dólar estadounidense'], dtype=object)

# %%
salarios=salarios[salarios['classif2.label']=='Divisa: Dólar estadounidense']

# %%
salarios['classif1.label'].replace({'Actividad económica (Agregada): Agricultura':'Agricultura',
       'Actividad económica (Agregada): Manufacturas':'Manufacturas',
       'Actividad económica (Agregada): Construcción':'Construcción',
       'Actividad económica (Agregada): Explotación de minas y canteras; Suministro de electricidad, gas y agua':'Explotación de minas y canteras; Suministro de electricidad, gas y agua',
       'Actividad económica (Agregada): Comercio, Transporte, Hoteles y Restaurantes, y actividades empresariales':'Comercio, Transporte, Hoteles y Restaurantes, y actividades empresariales',
       'Actividad económica (Agregada): Administración pública y servicios y actividades comunales y sociales':'Administración pública y servicios y actividades comunales y sociales','Actividad económica (CIIU-Rev.4): A. Agricultura; ganadería; silvicultura y pesca':'Agricultura; ganadería; silvicultura y pesca',
       'Actividad económica (CIIU-Rev.4): B. Explotación de minas y canteras':'Explotación de minas y canteras',
       'Actividad económica (CIIU-Rev.4): C. Industrias manufactureras':'Industrias manufactureras',
       'Actividad económica (CIIU-Rev.4): D. Suministro de electricidad, gas; vapor y aire acondicionado':'Suministro de electricidad, gas; vapor y aire acondicionado',
       'Actividad económica (CIIU-Rev.4): E. Suministro de agua; evacuación de aguas residuales, gestión de desechos y descontaminación':'Suministro de agua; evacuación de aguas residuales, gestión de desechos y descontaminación',
       'Actividad económica (CIIU-Rev.4): F. Construcción':'Construcción',
       'Actividad económica (CIIU-Rev.4): G. Comercio al por mayor y al por menor; reparación de vehículos automotores y motocicletas':'Comercio al por mayor y al por menor; reparación de vehículos automotores y motocicletas',
       'Actividad económica (CIIU-Rev.4): H. Transporte y almacenamiento':'Transporte y almacenamiento',
       'Actividad económica (CIIU-Rev.4): I. Actividades de alojamiento y de servicio de comidas':'Actividades de alojamiento y de servicio de comidas',
       'Actividad económica (CIIU-Rev.4): J. Información y comunicaciones':'Información y comunicaciones',
       'Actividad económica (CIIU-Rev.4): K. Actividades financieras y de seguros':'Actividades financieras y de seguros',
       'Actividad económica (CIIU-Rev.4): L. Actividades inmobiliarias':'Actividades inmobiliarias',
       'Actividad económica (CIIU-Rev.4): M. Actividades profesionales, científicas y técnicas':'Actividades profesionales, científicas y técnicas',
       'Actividad económica (CIIU-Rev.4): N. Actividades de servicios administrativos y de apoyo':'Actividades de servicios administrativos y de apoyo',
       'Actividad económica (CIIU-Rev.4): O. Administración pública y defensa; planes de seguridad social de afiliación obligatoria':'Administración pública y defensa; planes de seguridad social de afiliación obligatoria',
       'Actividad económica (CIIU-Rev.4): P. Enseñanza':'Enseñanza',
       'Actividad económica (CIIU-Rev.4): Q. Actividades de atención de la salud humana y de asistencia social':'Actividades de atención de la salud humana y de asistencia social',
       'Actividad económica (CIIU-Rev.4): R. Actividades artísticas, de entretenimiento y recreativas':'Actividades artísticas, de entretenimiento y recreativas',
       'Actividad económica (CIIU-Rev.4): S. Otras actividades de servicios':'Otras actividades de servicios',
       'Actividad económica (CIIU-Rev.4): T. Actividades de los hogares como empleadores; actividades no diferenciadas de los hogares como productores de bienes y servicios para uso propio':'Actividades de los hogares como empleadores; actividades no diferenciadas de los hogares como productores de bienes y servicios para uso propio',
       'Actividad económica (CIIU-Rev.4): U. Actividades de organizaciones y órganos extraterritoriales':'Actividades de organizaciones y órganos extraterritoriales','Actividad económica (CIIU-Rev.3.1): A. Agricultura, ganadería, caza y silvicultura':'',
       'Actividad económica (CIIU-Rev.3.1): B. Pesca':'Pesca',
       'Actividad económica (CIIU-Rev.3.1): C. Explotación de minas y canteras':'Explotación de minas y canteras',
       'Actividad económica (CIIU-Rev.3.1): D. Industrias manufactureras':'Industrias manufactureras',
       'Actividad económica (CIIU-Rev.3.1): E. Suministro de electricidad, gas y agua':'Suministro de electricidad, gas y agua',
       'Actividad económica (CIIU-Rev.3.1): F. Construcción':'Construcción',
       'Actividad económica (CIIU-Rev.3.1): G. Comercio al por mayor y al por menor; reparación de vehículos automotores, motocicletas, efectos personales y enseres domésticos':'Comercio al por mayor y al por menor; reparación de vehículos automotores, motocicletas, efectos personales y enseres domésticos',
       'Actividad económica (CIIU-Rev.3.1): H. Hoteles y restaurantes':'Hoteles y restaurantes',
       'Actividad económica (CIIU-Rev.3.1): I. Transporte, almacenamiento y comunicaciones':'Transporte, almacenamiento y comunicaciones',
       'Actividad económica (CIIU-Rev.3.1): J. Intermediación financiera':'Intermediación financiera',
       'Actividad económica (CIIU-Rev.3.1): K. Actividades inmobiliarias, empresariales y de alquiler':'Actividades inmobiliarias, empresariales y de alquiler',
       'Actividad económica (CIIU-Rev.3.1): L. Administración pública y defensa; planes de seguridad social de afiliación obligatoria':'Administración pública y defensa; planes de seguridad social de afiliación obligatoria',
       'Actividad económica (CIIU-Rev.3.1): M. Enseñanza':'Enseñanza',
       'Actividad económica (CIIU-Rev.3.1): N. Servicios sociales y de salud':'Servicios sociales y de salud',
       'Actividad económica (CIIU-Rev.3.1): O. Otras actividades de servicios comunitarios, sociales y personales':'Otras actividades de servicios comunitarios, sociales y personales',
       'Actividad económica (CIIU-Rev.3.1): P. Hogares privados con servicio doméstico':'Hogares privados con servicio doméstico',
       'Actividad económica (CIIU-Rev.3.1): Q. Organizaciones y órganos extraterritoriales':'Organizaciones y órganos extraterritoriales','Actividad económica (CIIU-Rev.2): 1. Agricultura, caza, silvicultura y pesca':'Agricultura, caza, silvicultura y pesca',
       'Actividad económica (CIIU-Rev.2): 2. Explotación de minas y canteras':'Explotación de minas y canteras',
       'Actividad económica (CIIU-Rev.2): 3. Industrias manufactureras':'Industrias manufactureras',
       'Actividad económica (CIIU-Rev.2): 4. Electricidad, gas y agua':'Electricidad, gas y agua',
       'Actividad económica (CIIU-Rev.2): 5. Construcción':'Construcción',
       'Actividad económica (CIIU-Rev.2): 6. Comercio al por mayor y al por menor y restaurantes y hoteles':'Comercio al por mayor y al por menor y restaurantes y hoteles',
       'Actividad económica (CIIU-Rev.2): 7. Transportes, almacenamiento y comunicaciones':'Transportes, almacenamiento y comunicaciones',
       'Actividad económica (CIIU-Rev.2): 8. Establecimientos financieros, seguros, bienes inmuebles y servicios prestados a las empresas':'Establecimientos financieros, seguros, bienes inmuebles y servicios prestados a las empresas',
       'Actividad económica (CIIU-Rev.2): 9. Servicios comunales, sociales y personales':'Servicios comunales, sociales y personales'},inplace=True)

# %%
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (Agregada): Total', :]
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (Agregada): Sin clasificar', :]
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (CIIU-Rev.4): Total', :]
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (CIIU-Rev.4): X. No clasificados en otra parte', :]
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (CIIU-Rev.3.1): Total', :]
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (CIIU-Rev.3.1): X. No clasificados en otra parte', :]
salarios=salarios.loc[salarios['classif1.label'] != 'Actividad económica (CIIU-Rev.2): Total', :]

# %%
salarios['sex.label'].replace({'Sexo: Total':'Total','Sexo: Hombres':'Male','Sexo: Mujeres':'Female'},inplace=True)

# %%
salarios.rename(columns={'ref_area.label':'Country','sex.label':'Gender','ref_area.label':'Country','classif1.label':'Activity','classif2.label':'Currency','time':'Year','obs_value':'Amount',},inplace=True)

# %%
salarios
# Out:
#              Country Gender  \
# 493        Argentina  Total
# 496        Argentina  Total
# 499        Argentina  Total
# 502        Argentina  Total
# 505        Argentina  Total
# ...              ...    ...
# 78059  United States  Total
# 78061  United States  Total
# 78067  United States  Total
# 78069  United States  Total
# 78071  United States  Total
#
#                                                 Activity  \
# 493                                          Agricultura
# 496                                         Manufacturas
# 499                                         Construcción
# 502    Explotación de minas y canteras; Suministro de...
# 505    Comercio, Transporte, Hoteles y Restaurantes, ...
# ...                                                  ...
# 78059                          Industrias manufactureras
# 78061                                       Construcción
# 78067                    Explotación de minas y canteras
# ...

# %%
salarios.isna().sum()
# Out:
# Country     0
# Gender      0
# Activity    0
# Currency    0
# Year        0
# Amount      0
# dtype: int64

# %%
tabla_7.to_csv('tabla_general.csv')
edad_migraciones.to_csv('tabla_edad_sexo_migrantes.csv')
salarios.to_csv('tabla_salario_actividad.csv')

# %%
edad_migraciones[edad_migraciones['Year'].isin([2020,2015,2010,2005,2000,1995,1990])]
# Out:
#              Country  Gender    Age  Year  Population
# 110        Argentina   Total    15+  2020   1330014.0
# 114        Argentina   Total  15-64  2020   1042196.0
# 118        Argentina   Total  15-24  2020    138287.0
# 122        Argentina   Total    25+  2020   1191727.0
# 126        Argentina    Male    15+  2020    616127.0
# ...              ...     ...    ...   ...         ...
# 19838  United States  Female  Total  1995  11929843.0
# 19841  United States  Female  15-24  1995   1632232.0
# 19844  United States  Female  25-54  1995   7211868.0
# 19847  United States  Female  55-64  1995   1298033.0
# 19850  United States  Female    65+  1995   1787711.0
#
# [991 rows x 5 columns]

# %%
tabla_7
# Out:
#      Year    Country  Emigrants  International migrants  Net migration  \
# 0    1990  Argentina   430155.0               1649919.0       160000.0
# 1    1995  Argentina   481968.0               1595069.0      -105000.0
# 2    2000  Argentina   555542.0               1540219.0      -128000.0
# 3    2005  Argentina   805291.0               1674163.0      -125000.0
# 4    2010  Argentina   938639.0               1805957.0      -120000.0
# ..    ...        ...        ...                     ...            ...
# 156  2000  Venezuela   317753.0               1013738.0        -4540.0
# 157  2005  Venezuela   437087.0               1076474.0       -22740.0
# 158  2010  Venezuela   560528.0               1347347.0      -200220.0
# 159  2015  Venezuela   709140.0               1404448.0      -431040.0
# 160  2020  Venezuela  5415337.0               1324193.0     -3266243.0
#
#      Net migration rate  Population  relative migration  \
# 0                 1.019    32637658            0.013180
# ...

# %%
tabla_final=pd.read_csv(r'Tabla_final.csv')

# %%
tabla_final.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Year', 'Country', 'Emigrants',
#        'International migrants', 'Net migration', 'Net migration rate',
#        'Population', 'relative migration', 'relative migration net',
#        'Inmigrants', 'Inflation', 'PBI', 'Female population',
#        'Female population aged 20 to 29 years',
#        'Female population aged 30 to 39 years',
#        'Female population aged 40 to 49 years',
#        'Female population aged 50 to 59 years',
#        'Female population aged 60 to 69 years', 'Male population',
#        'Male population aged 20 to 29 years',
#        'Male population aged 30 to 39 years',
#        'Male population aged 40 to 49 years',
#        'Male population aged 50 to 59 years',
#        'Male population aged 60 to 69 years', 'Population aged 20 to 29 years',
#        'Population aged 30 to 39 years', 'Population aged 40 to 49 years',
#        'Population aged 50 to 59 years', 'Population aged 60 to 69 years',
# ...

# %%
tabla_final['Inverse Inflation']=100-tabla_final['Inflation']

# %%
tabla_final['Inverse Inflation']
# Out:
# 0     -2213.96
# 1        96.62
# 2       100.94
# 3        90.36
# 4        89.22
#         ...
# 156      83.80
# 157      84.05
# 158      71.81
# 159     -21.74
# 160   -2859.80
# Name: Inverse Inflation, Length: 161, dtype: float64

# %%
tabla_final_2.columns
# Out:
# Index(['Year', 'Country', 'Emigrants', 'International migrants',
#        'Net migration', 'Net migration rate', 'Population',
#        'relative migration', 'relative migration net', 'Inmigrants',
#        'Inflation', 'PBI', 'Female population',
#        'Female population aged 20 to 29 years',
#        'Female population aged 30 to 39 years',
#        'Female population aged 40 to 49 years',
#        'Female population aged 50 to 59 years',
#        'Female population aged 60 to 69 years', 'Male population',
#        'Male population aged 20 to 29 years',
#        'Male population aged 30 to 39 years',
#        'Male population aged 40 to 49 years',
#        'Male population aged 50 to 59 years',
#        'Male population aged 60 to 69 years', 'Population aged 20 to 29 years',
#        'Population aged 30 to 39 years', 'Population aged 40 to 49 years',
#        'Population aged 50 to 59 years', 'Population aged 60 to 69 years',
# ...

# %%
tabla_final[tabla_final['Country']=='Argentina'].iloc[:,[2,10]]
# Out:
#    Year  relative migration net
# 0  1990                0.004902
# 1  1995               -0.003005
# 2  2000               -0.003453
# 3  2005               -0.003199
# 4  2010               -0.002920
# 5  2015                0.000694
# 6  2020                0.000533

# %%
sns.heatmap(tabla_final[tabla_final['Country']=='Argentina'].iloc[:,2:10].corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_16008\1711025059.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tabla_final[tabla_final['Country']=='Argentina'].iloc[:,2:10].corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')
# <AxesSubplot:>

# %%
tabla_final[tabla_final['Country']=='Argentina'].iloc[:,[2,10]]
# Out:
#    Year  relative migration net
# 0  1990                0.004902
# 1  1995               -0.003005
# 2  2000               -0.003453
# 3  2005               -0.003199
# 4  2010               -0.002920
# 5  2015                0.000694
# 6  2020                0.000533

# %%
regiones=pd.read_csv('regiones.csv')

# %%
tabla_final.to_sql('tf',conn,index=False)
regiones.to_sql('re',conn,index=False)
# Out:
# 23

# %%
tabla_final
# Out:
#      Unnamed: 0.1  Unnamed: 0  Year    Country  Emigrants  \
# 0               0           0  1990  Argentina   430155.0
# 1               1           1  1995  Argentina   481968.0
# 2               2           2  2000  Argentina   555542.0
# 3               3           3  2005  Argentina   805291.0
# 4               4           4  2010  Argentina   938639.0
# ..            ...         ...   ...        ...        ...
# 156           156         156  2000  Venezuela   317753.0
# 157           157         157  2005  Venezuela   437087.0
# 158           158         158  2010  Venezuela   560528.0
# 159           159         159  2015  Venezuela   709140.0
# 160           160         160  2020  Venezuela  5415337.0
#
#      International migrants  Net migration  Net migration rate  Population  \
# 0                 1649919.0       160000.0               1.019    32637658
# 1                 1595069.0      -105000.0              -0.623    34946116
# ...

# %%
regiones
# Out:
#           Country           Region
# 0       Argentina    South America
# 1        Barbados        Caribbean
# 2         Bolivia    South America
# 3          Brazil    South America
# 4          Canada    North America
# 5           Chile    South America
# 6        Colombia    South America
# 7      Costa Rica  Central America
# 8         Ecuador    South America
# 9     El Salvador  Central America
# 10      Guatemala  Central America
# 11         Guyana    South America
# 12          Haiti        Caribbean
# 13       Honduras  Central America
# 14        Jamaica        Caribbean
# 15         Mexico  Central America
# 16      Nicaragua  Central America
# 17         Panama  Central America
# 18       Paraguay    South America
# 19           Peru    South America
# 20  United States    North America
# 21        Uruguay    South America
# 22      Venezuela    South America

# %%
tabla_final_2=pd.read_sql('SELECT tf.*,re.Region FROM tf tf JOIN re re ON(tf.Country=re.country)',conn)

# %%
tabla_final_2.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
tabla_final_2.to_csv('Tabla_final.csv',index=False)
