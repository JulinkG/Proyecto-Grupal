# %%
import pandas as pd
from sqlite3 import connect

# %% [markdown]
# ## *URL Data*

# %%
##Información necesaria:

##- Retornos, voluntarios, no voluntarios, retornos totales, por país y año

##- migrantes documentados (legales), e ilegales, por país y año

##- éxito de migración (gente que no logra llegar, muerte, secuestro, trata)

##- salario POR AÑO

url_1='https://ourworldindata.org/world-population-growth' #ejemplo

# %%
"""1."Argentina","Bolivia", "Brazil","Canada","Colombia", morales
2."Costa Rica", "Cuba", "Chile", "Ecuador","El Salvador", alexander
3."Guatemala", "Haiti", "Honduras", "Jamaica", "Mexico", rolando
4."Nicaragua", "Panama", "Paraguay", "Peru","Puerto Rico","Jamaica" flores
5."United States","Uruguay","Venezuela","Bahamas","Barbados","Guyanaj, ulian"""

# %%
flujo=pd.read_csv(r'migration-flows.csv')

# %%
flujo.iloc[:,0:10]
# Out:
#       Year      Country  Emigrants from Afghanistan  \
# 0     1990  Afghanistan                  -7679582.0
# 1     1995  Afghanistan                  -4347049.0
# 2     2000  Afghanistan                  -4750677.0
# 3     2005  Afghanistan                  -4116739.0
# 4     2010  Afghanistan                  -5269518.0
# ...    ...          ...                         ...
# 1654  2000     Zimbabwe                         NaN
# 1655  2005     Zimbabwe                         NaN
# 1656  2010     Zimbabwe                         NaN
# 1657  2015     Zimbabwe                         NaN
# 1658  2020     Zimbabwe                         NaN
#
#       Immigrants to Afghanistan  Emigrants from Albania  \
# 0                       57686.0                     NaN
# 1                       71522.0                     NaN
# 2                       75917.0                     NaN
# 3                       87314.0                     NaN
# ...

# %%
flujo.iloc[:,10:20]
# Out:
#       Emigrants from Andorra  Immigrants to Andorra  Emigrants from Angola  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 1654                     NaN                    NaN                    NaN
# 1655                     NaN                    NaN                    NaN
# 1656                     NaN                    NaN                    NaN
# 1657                     NaN                    NaN                    NaN
# 1658                     NaN                    NaN                    NaN
#
# ...

# %%
flujo.iloc[:,20:30]
# Out:
#       Emigrants from Armenia  Immigrants to Armenia  Emigrants from Aruba  \
# 0                        NaN                    NaN                   NaN
# 1                        NaN                    NaN                   NaN
# 2                        NaN                    NaN                   NaN
# 3                        NaN                    NaN                   NaN
# 4                        NaN                    NaN                   NaN
# ...                      ...                    ...                   ...
# 1654                     NaN                    NaN                   NaN
# 1655                     NaN                    NaN                   NaN
# 1656                     NaN                    NaN                   NaN
# 1657                     NaN                    NaN                   NaN
# 1658                     NaN                    NaN                   NaN
#
#       Immigrants to Aruba  Emigrants from Australia  Immigrants to Australia  \
# ...

# %%
flujo.iloc[:,100:110]
# Out:
#       Emigrants from Costa Rica  Immigrants to Costa Rica  \
# 0                           NaN                     -25.0
# 1                           NaN                     -11.0
# 2                           NaN                      -3.0
# 3                           NaN                      -3.0
# 4                           NaN                      -5.0
# ...                         ...                       ...
# 1654                        NaN                      -1.0
# 1655                        NaN                      -2.0
# 1656                        NaN                      -2.0
# 1657                        NaN                      -1.0
# 1658                        NaN                      -1.0
#
#       Emigrants from Cote d'Ivoire  Immigrants to Cote d'Ivoire  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# ...

# %%
conn = connect(':memory:') 
flujo.to_sql('flu',conn,index=False)
# Out:
# 1659

# %%
flujo_america=pd.read_sql('SELECT Year,Country,`Emigrants from Argentina`,`Immigrants to Argentina`,`Emigrants from Bolivia`,`Immigrants to Bolivia`,`Emigrants from Brazil`,`Immigrants to Brazil`,`Emigrants from Canada`,`Immigrants to Canada`,`Emigrants from Colombia`,`Immigrants to Colombia`,`Emigrants from Costa Rica`,`Immigrants to Costa Rica`,`Emigrants from Chile`,`Immigrants to Chile`,`Emigrants from Cuba`,`Immigrants to Cuba`,`Emigrants from Ecuador`,`Immigrants to Ecuador`,`Emigrants from El Salvador`,`Immigrants to El Salvador` FROM flu WHERE Country IN ("Argentina","Belice","Bolivia", "Brazil","Canada","Colombia", "Costa Rica", "Cuba", "Chile", "Ecuador", "El Salvador", "Guatemala", "Haiti", "Honduras", "Jamaica", "Mexico", "Nicaragua", "Panama", "Paraguay", "Peru","Puerto Rico", "Republica Dominicana","United States","Uruguay","Venezuela","Antigua y Barbuda","Bahamas","Barbados","Dominica","Granada","Guyana","Jamaica","República Dominicana","San Cristobal y Nieves","San Vicente y las Granadinas","Santa Lucia")',conn)

# %%
flujo_america
# Out:
#      Year    Country  Emigrants from Argentina  Immigrants to Argentina  \
# 0    1990  Argentina                 -430155.0                1649919.0
# 1    1995  Argentina                 -481968.0                1595069.0
# 2    2000  Argentina                 -555542.0                1540219.0
# 3    2005  Argentina                 -805291.0                1674163.0
# 4    2010  Argentina                 -938639.0                1805957.0
# ..    ...        ...                       ...                      ...
# 184  2000  Venezuela                    8724.0                  -2600.0
# 185  2005  Venezuela                    9078.0                  -1919.0
# 186  2010  Venezuela                    9542.0                  -1236.0
# 187  2015  Venezuela                    9944.0                  -1240.0
# 188  2020  Venezuela                    9374.0                -176369.0
#
#      Emigrants from Bolivia  Immigrants to Bolivia  Emigrants from Brazil  \
# ...

# %%
salarios=pd.read_csv(r'salarios.csv')
# Out:
# C:\Users\gualas\AppData\Local\Temp\ipykernel_18648\3779403627.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   salarios=pd.read_csv(r'salarios.csv')

# %%
salarios
# Out:
#                             ref_area.label  \
# 0                                Argentina
# 1                                Argentina
# 2                                Argentina
# 3                                Argentina
# 4                                Argentina
# ...                                    ...
# 68865  Venezuela, República Bolivariana de
# 68866  Venezuela, República Bolivariana de
# 68867  Venezuela, República Bolivariana de
# 68868  Venezuela, República Bolivariana de
# 68869  Venezuela, República Bolivariana de
#
#                                          indicator.label  \
# 0      Ganancias mensuales promedio de los asalariado...
# 1      Ganancias mensuales promedio de los asalariado...
# 2      Ganancias mensuales promedio de los asalariado...
# 3      Ganancias mensuales promedio de los asalariado...
# 4      Ganancias mensuales promedio de los asalariado...
# ...                                                  ...
# ...

# %% [markdown]
# ## *Web Scraping*

# %% [markdown]
# ## *Limpieza*

# %% [markdown]
# ## *Comparacion y Actualizacion*

# %% [markdown]
# ## *Machine Learning*

# %% [markdown]
# ## *Credenciales*
